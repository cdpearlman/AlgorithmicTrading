# %% [markdown]
# # This file is for functional strategies only!

# %%
def add_trend_signal(df):
    df['Trend'] = 0
    for i in range(5, len(df)):
        window = df.iloc[i-5:i]
        if all(window['Close'] > window['EMA_200']):
            df.loc[i, 'Trend'] = 1
        elif all(window['Close'] < window['EMA_200']):
            df.loc[i, 'Trend'] = -1

    return df

# %%
def add_total_signal(df):
    # Strategy: Trade with trend, rsi > 50, and engulfing candle
    # Trade Management: Stop loss @ 2x candle width, 1.5 risk to reward ratio
    # -------------------------------------------------------------------------------
    # Trial 1: Very negative returns, going to try just buys
    # Trial 2: Only did buy positions, positive returns, not as high as buy & hold returns
    # Results: ~35% win rate with positive decent returns (14.5%) for 2.0 ratio
    
    # df['engulfing_signal'] = 0
    # df.loc[ (df['Close'] > df['EMA_200']) & (df['RSI'] > 50) & (df['Engulfing'] == 100), 'engulfing_signal'] = 1

    # Strategy: Trade with trend, if candle closes outside of bollinger bands, make a limit order at 3% below closing price
    # Trade Management: Limit order is valid for 5 days, stop loss @ 3% below limit, 1.5 risk to reward ratio
    # -------------------------------------------------------------------------------
    # Trial 1: ~40% win rate with positive decent returns (11.5%) for 1.9 ratio
    # Trail 2: Sell when RSI crosses 50 line, much better returns (~27%)
    # Trial 3: Same trade management, only buy signals. ~45% return rate and 72% win rate
    df['bb_signal'] = 0
    df.loc[ (df['Trend'] == 1) & (df['Close'] < df['BBL_20_2.0']), 'bb_signal'] = 1
    # df.loc[ (df['Trend'] == -1) & (df['Close'] > df['BBU_20_2.0']), 'bb_signal'] = -1

    # Strategy: Trade with trend, look for MACD crossover above or below the zero line
    # Trade Management: Optimize parameters for sl and tp
    # -------------------------------------------------------------------------------
    # Trial 1: ~ 60% win rate with ~16% return rate, begin paper trade testing
    # df['macd_signal'] = 0
    # df.loc[ (df['Trend'] == 1) & (df['MACD_cross'] == 1) & (df['MACD_12_26_9'] < 0), 'macd_signal'] = 1

    #Strategy: Trade with trend, buy if 5-day RSI is down 3 days in a row, drops below 30
    # Trade Management: Sell when 5-day RSI crosses back above 50
    # ---------------------------------------------------------------------------------
    # Trial 1: Return rate is low, but win rate is near 60%, moving to paper trading 
    df['rsi_signal'] = 0  # Signal column to store buy/sell signals

    for i in range(3, len(df)):
        # Buy signal: 50-day MA crosses above 200-day MA (Golden Cross) and RSI is between 40 and 60
        if (df.loc[i - 2, 'RSI_5'] > df.loc[i - 1, 'RSI_5']) and (df.loc[i - 1, 'RSI_5'] > df.loc[i, 'RSI_5']) and (df.loc[i, 'RSI_5'] < 30) and (df.loc[i - 2, 'RSI_5'] < 60) and (df.loc[i, 'Close'] > df.loc[i, 'SMA_200']):
            df.loc[i, 'rsi_signal'] = 1  # Buy signal

    return df

# %%
import yfinance as yf
# from yahoo_fin import stock_info as si
import pandas_ta as ta
import numpy as np
import pandas as pd

def import_data(stock, startDate):
    data = yf.download(stock, start=startDate, interval='1d')

    data['EMA_200'] = ta.ema(data['Close'], length=200)
    data['SMA_50'] = ta.sma(data['Close'], length=50)
    data['SMA_200'] = ta.sma(data['Close'], length=200)
    data['RSI'] = ta.rsi(data['Close'], length=14)
    data['RSI_5'] = ta.rsi(data['Close'], length=5)
    data['ATR'] = ta.atr(data['High'], data['Low'], data['Close'], length=14)
    # data['Engulfing'] = data.ta.cdl_pattern(name="engulfing")
    bbands = ta.bbands(data['Close'], length=20, std=2)
    macd = ta.macd(data['Close'])
    data = data.join(bbands)
    data = data.join(macd)
    
    data.reset_index(inplace=True)
    
    data = add_trend_signal(data)
    # data = add_macd_signal(data)
    data = add_total_signal(data)
    # data = add_sma_signal(data)

    return data

# %%
def calc_bb(ticker, risk):
    df = import_data(ticker, '2022-01-01')
    today = df.iloc[-2]
    curr = today.Close
    order = curr - (curr * .03)
    stop = order - (order * .03)
    shares = risk / (order - stop)

    order = round(order, 2)
    shares = round(shares, 2)

    print(f'Buy {ticker} at {order}, Shares: {shares}')

# %%
def calc_rsi(ticker, risk):
    df = import_data(ticker, '2022-01-01')
    today = df.iloc[-1]
    curr = today.Close
    stop = curr - (curr * .03)
    shares = risk / (curr - stop)

    curr = round(curr, 2)
    shares = round(shares, 2)

    print(f'Buy {ticker} at {curr}, Shares: {shares}')

# %%
def find_buys():
    bb_buys = []
    rsi_buys = []
    sp500_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    sp500_table = pd.read_html(sp500_url)
    TICKERS = sp500_table[0]['Symbol'].tolist()

    for ticker in TICKERS:
        try:
            df = import_data(ticker, '2023-01-01')
            rsi_signal = df.iloc[-1]['rsi_signal']
            bb_signal = df.iloc[-2]['bb_signal']
            # macd_signal = df.iloc[-1]['macd_signal']
            # if engulfing_signal == 1:
            #     engulfing_buys.append(ticker)
            if bb_signal != 0:
                bb_buys.append(ticker)
            if rsi_signal != 0:
                rsi_buys.append(ticker)
        except Exception as e:
            print(ticker, e)

    print(f'BB Buy Signals: {bb_buys}')
    for ticker in bb_buys:
        calc_bb(ticker, 20)
        # calc_bb(ticker, 1000)
    print(f'RSI Buy Signals: {rsi_buys}')
    for ticker in rsi_buys:
        calc_rsi(ticker, 20)
    # print(f'MACD Signals: {macd_buys}')
    # for ticker in macd_buys:
    #     calc_macd(ticker)

# %%
# # import alpaca_trade_api as tradeapi

# # Function to make a limit order
# def make_alpaca_trade(symbol, qty, side='buy', time_in_force='day'):
#     """
#     Places a limit order using the Alpaca API.

#     Parameters:
#     - symbol (str): The stock symbol to trade (e.g., 'AAPL')
#     - qty (int): Number of shares to buy/sell
#     - side (str): 'buy' or 'sell'
#     - limit_price (float): The price at which to execute the limit order
#     - time_in_force (str): 'day', 'gtc', 'opg', 'cls', 'ioc', or 'fok' (default is 'gtc')
#     """
#     # Replace these with your own API key and secret
#     API_KEY = 'PK0AMXVEUOAC76WYAX69'
#     API_SECRET = 'yKA05lJuC0C38C70amoyJoswtl1SM59omIDIwRPK'
#     BASE_URL = 'https://paper-api.alpaca.markets'  # For paper trading, change to live URL for live trading

#     # Initialize the API
#     api = tradeapi.REST(API_KEY, API_SECRET, BASE_URL, api_version='v2')

#     print("connected")
#     try:
#         # Create the limit order
#         order = api.submit_order(
#             symbol=symbol,
#             qty=qty,
#             side=side,
#             type='market',
#             time_in_force=time_in_force
#         )
#         print(f'Order went through')
#         return order
#     except Exception as e:
#         print(f"An error occurred: {e}")

# # Example usage:
# # make_alpaca_trade(symbol="AAPL", qty=1, side="buy", limit_price=150.00)

# %%
def make_rsi_purchases():
    curr_positions = ['SWK', 'STE', 'MTD', 'MRO', 'KVUE', 'GIS', 'FSLR', 'FFIV', 'FCX', 'ERIE', 'EFX', 'CTLT', 'CF', 'ACGL', 'ABBV', 'EOG', 'TSLA']
    rsi_buy = ['MO', 'BBY', 'BLDR', 'CHTR', 'EMN', 'EBAY', 'EOG', 'HD', 'MPWR', 'XYL']

    API_KEY = "PK0AMXVEUOAC76WYAX69"
    API_SECRET = "yKA05lJuC0C38C70amoyJoswtl1SM59omIDIwRPK"
    BASE_URL = "https://paper-api.alpaca.markets"  # Use "https://api.alpaca.markets" for live trading

    # Initialize the Alpaca API
    api = tradeapi.REST(API_KEY, API_SECRET, BASE_URL, api_version='v2')

    # Fetch the current positions
    positions = api.list_positions()
    price = 2500 / (len(curr_positions) + len(rsi_buy))
    
    for position in positions:
        df = import_data(position.symbol, '2024-01-01')
        close = df.iloc[-1]['Close']
        shares = price / close
        difference = float(position.qty) - shares
        if difference > 0:
            print(f'Selling {position.symbol} at {difference} shares')
            make_alpaca_trade(position.symbol, abs(difference), side = 'sell')
        else:
            print(f'Buying {position.symbol} at {difference} shares')
            make_alpaca_trade(position.symbol, abs(difference), side = 'buy')
    for ticker in rsi_buy:
        df = import_data(ticker, '2024-01-01')
        close = df.iloc[-1]['Close']
        shares = price / close
        print(f'Buying {ticker} at {shares} shares')
        make_alpaca_trade(ticker, shares, side = 'buy')

# %%
'''
Positions:
10/21
BBY, BLDR, EFX, GIS, MPWR, POOL, PSA, TXN

10/22
DHR, DHI, GE, HAS, IPG, KMB, LEN, MHK, NTAP, NOC, PHM, SHW, WAT, WY, XYL

10/23
AVY, CTLT, KO, DECK, HPE, KEYS, LMT, STX, SWK, TMO

10/24
CARR, DOV, FFIV, FTV, IR, KDP, NEM, RVTY, ROL, SPGI, LUV, TXT, TSCO, UNP, VLTO, ZTS

10/25
AFL, CLX, CL, HIG, HCA, PGR, UHS, VZ
'''
# Out:
# '\nPositions:\n10/21\nBBY, BLDR, EFX, GIS, MPWR, POOL, PSA, TXN\n\n10/22\nDHR, DHI, GE, HAS, IPG, KMB, LEN, MHK, NTAP, NOC, PHM, SHW, WAT, WY, XYL\n\n10/23\nAVY, CTLT, KO, DECK, HPE, KEYS, LMT, STX, SWK, TMO\n\n10/24\nCARR, DOV, FFIV, FTV, IR, KDP, NEM, RVTY, ROL, SPGI, LUV, TXT, TSCO, UNP, VLTO, ZTS\n\n10/25\nAFL, CLX, CL, HIG, HCA, PGR, UHS, VZ\n'

# %%
# make_rsi_purchases()
find_buys()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MMM']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# MMM 'NoneType' object is not iterable
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AOS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# AOS 'NoneType' object is not iterable
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABT']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# ABT 'NoneType' object is not iterable
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ABBV']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# ABBV 'NoneType' object is not iterable
# ...
